# %% [markdown]
# This notebook contains the code for making predictions on a test file. <br>
#  - *This notebook was made in Google Colab, and requires GPU runtime.* <br>
#  - *No training files or submission files need to be added in notebook. <br>Data is being implicitly downloaded in the notebook.* <br>.

# %% [markdown]
# # Pre-requisites
# Necessary imports, preprocessed data downloads and intialization

# %% [markdown]
# ##### Install libraries

# %%
# %%capture
# !pip install catboost
# !pip install lasio

# %% [markdown]
# ##### Import

# %%
import numpy as np 
import pandas as pd 

import os
import lasio 
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split
import xgboost as xg
from catboost import CatBoostRegressor
import random

from sklearn.metrics import mean_squared_error as MSE

import time
import warnings
warnings.filterwarnings('ignore')

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed = 42
seed_everything(seed)

# %% [markdown]
# ##### Alias Dictionary

# %%
# False dict
alias_dict_F = dict()

alias_dict_F['li_DEC_D'] = ['DPHZ', 'DPHI_LS', 'DPHI', 'DPOR_LS', 'DPO_LS', 'DPHZ_LS'] # from density
alias_dict_F['li_DEC_N'] = ['NPOR_LS', 'ENPH_LS', 'NPHI_LS', 'APLC_LS', 'NPHI_LS_1', 'NPHI', 'SNP'] # from Neutron
alias_dict_F['li_DEC_T'] = ['TNPH_LS_1', 'TNPH_LS', 'TPHI_LS', 'TNPH', 'CNPOR_LS', 'TNPH_LIM'] # thermal
alias_dict_F['li_DEC_S'] = ['SPHI', 'SPHI_LS'] # sonic
alias_dict_F['li_DEC_NOR'] = ['PORS_LS', 'PXND', 'PORZ_LS'] # normal

alias_dict_F['li_USF_S'] = ['DTS', 'DT4ST', 'DT4SR', 'DT1', 'DT4S', 'DTSH', 'DT1T', 'DTTS', 'DTRS', 'DT1R', 'DT2R', 'DTST', 'DT2'] # shear
alias_dict_F['li_USF_P'] = ['DTCO','DT4PR', 'DT4PT', 'DTCO_1', 'DT4P', 'DTTP'] # compressional
alias_dict_F['li_USF_LO'] = ['DTC', 'DT', 'DTLN', 'DTLF', 'DTL'] # long spacing 

alias_dict_F['li_GAPI_D'] = ['GRD1', 'CGRD', 'GRD', 'HCGRD', 'HSGRD'] # density
alias_dict_F['li_GAPI_R'] = ['HCGRR', 'CGRR', 'GRR', 'GRR_R', 'GRR_R2', 'GRR_R1'] # Resistivity
alias_dict_F['li_GAPI_S'] = ['GRS1', 'CGRS', 'ECGRS', 'HSGRS', 'HCGRS'] # Sonic
alias_dict_F['li_GAPI_N'] = ['HGRT', 'GRC', 'GR_EDTC', 'GR', 'ECGREDTC', 'GRT'] # Normal
alias_dict_F['li_GAPI_SPEC'] = ['SGRR', 'HSGR', 'SGRD', 'SGRDD', 'SGR', 'SGRS'] # spectroscopy

alias_dict_F['li_IN_D'] = ['LCALD', 'CALD', 'CALI', 'LCAL', 'LCAL_1'] # density
alias_dict_F['li_IN_R'] = ['CALSR', 'CAL1R', 'CAL1R_R', 'CALSR_R', 'CALR'] # resistivity
alias_dict_F['li_IN_HILT'] = ['HCALS', 'HCAL', 'HCAL_2', 'HCALD', 'HCALR', 'HCAL_1'] # hilt
alias_dict_F['li_IN_HD'] = ['HD2', 'HD1', 'HD', 'HD1_PPC1', 'HDS', 'HD2_PPC2', 'HD2_PPC1'] # hd
alias_dict_F['li_IN_N'] = ['CALX', 'C1', 'C2', 'DCAL'] # normal

alias_dict_F['li_SH'] = ['AE10','AF10','AHT10','AT10','HLLS','HMIN','HMNO','LLS','LLS_R','LLS_R1','LLS_R2','MSFL','MSFL_R','RXO8','SFLU']
alias_dict_F['li_DP'] =['AHT90', 'AF90', 'ILD', 'AT90', 'HRID', 'AE90', 'LLD_R1', 'LLD_R2', 'RT_HRLT', 'LLD', 'HLLD', 'LLD_R']
alias_dict_F['li_MD'] = ['AE20','AE30','AF20','AHT20','AHT30','AT20','AT30','AO30','ILM','TBIT20','ILM','ILM_1','IMBC','IMPH','RXOZ','RXOZ_R','RXO_HRLT']
alias_dict_F['li_RLA'] = ['RLA1','RLA2','RLA3','RLA4','RLA5']

alias_dict_F['li_BE'] = ['PEFL', 'PEFZ', 'PE', 'PEF']

alias_dict_F['li_MV'] = ['SPR']

alias_dict_F['li_LBF_D'] = ['TEND_1', 'TEND1', 'TEND'] # density
alias_dict_F['li_LBF_R'] = ['TENR_R', 'TENR_R', 'TENR_R2', 'TENR', 'TENR_R1'] # resistivity
alias_dict_F['li_LBF_S'] = ['TENS1', 'LTEN', 'TENS'] # sonic
alias_dict_F['li_LBF_N'] = ['TENT', 'TEN'] # normal


alias_F = {"DTSM" :['DTSM'],
         "DEC_D"  : alias_dict_F['li_DEC_D'],
         "DEC_N"  : alias_dict_F['li_DEC_N'],
         "DEC_T"  : alias_dict_F['li_DEC_T'],
         "DEC_S"  : alias_dict_F['li_DEC_S'],
         "DEC_NOR"  : alias_dict_F['li_DEC_NOR'],

         "USF_S"  : alias_dict_F['li_USF_S'],
         "USF_P"  : alias_dict_F['li_USF_P'],
         "USF_LO"  : alias_dict_F['li_USF_LO'],

         "GAPI_D" : alias_dict_F['li_GAPI_D'],
         "GAPI_R" : alias_dict_F['li_GAPI_R'],
         "GAPI_S" : alias_dict_F['li_GAPI_S'],
         "GAPI_N" : alias_dict_F['li_GAPI_N'],
         "GAPI_SPEC" : alias_dict_F['li_GAPI_SPEC'],

         "IN_D"   : alias_dict_F['li_IN_D'],
         "IN_R"   : alias_dict_F['li_IN_R'],
         "IN_HILT"   : alias_dict_F['li_IN_HILT'],
         "IN_N"   : alias_dict_F['li_IN_N'],

         "MV"   : alias_dict_F['li_MV'],

         "BE"   : alias_dict_F['li_BE'],

         "LBF_D"  : alias_dict_F['li_LBF_D'],
         "LBF_R"  : alias_dict_F['li_LBF_R'],
         "LBF_S"  : alias_dict_F['li_LBF_S'],
         "LBF_N"  : alias_dict_F['li_LBF_N'],

         "SH"   : alias_dict_F['li_SH'],
         "DP"   : alias_dict_F['li_DP'], 
         "RL"   : alias_dict_F['li_RLA']
 }
#########################################################

# True dict 
alias_dict_T = dict()
alias_dict_T['li_SH'] = ['AT10', 'AE10', 'AHT10', 'LLS', 'SFL', 'AST10'] # shallow
alias_dict_T['li_MD'] = ['AE20', 'IMBC', 'AF20','AE30', 'ILM_1', 'AST30', 'IMPH', 'AHT30','ILM', 'AHT20', 'TBIT20', 'TBIT30'] # Medium
alias_dict_T['li_DP'] = ['ILD1', 'ILD_1', 'AT90', 'AE90', 'AST90', 'LLD', 'ILD', 'AHT90', 'IDPH'] # deep
alias_dict_T['li_SFL'] = ['SFLA', 'SFLU', 'SFLU', 'SFLU_1', 'RILD']
alias_dict_T['li_RLA'] = ['RLA3', 'RLA1', 'RLA5']

alias_dict_T['li_DEC_NP'] = ['NPHI', 'NPOR', 'NPHI_LS', 'NPOR_LS', 'NPHS', 'NPHI1', 'CNC'] # Neutron
alias_dict_T['li_DEC_DP'] = ['DPHZ2', 'DPHZ_LS', 'DPHI_LS', 'DPHI', 'DPOR', 'DPHI_SLDT', 'DPHZ', 'PORZ', 'DPO_LS', 'DPO'] # Density
alias_dict_T['li_DEC_ST'] = ['SPHI_SS', 'SPHI', 'TNPH_LS', 'SPHI_LS'] # Sonic

alias_dict_T['li_USF_S'] = ['DT1', 'DTSM_SLOW', 'DTSM_FAST', 'DT4S', 'DTRS', 'DTC', 'DTTS', 'DTS', 'DTMD', 'DTST', 'DT', 'DTOT', 'DTM'] # Shear
alias_dict_T['li_USF_P'] = ['DT4P', 'DTRP', 'DTTP', 'DTC', 'DTCO_1', 'DTCO', 'DT'] # Compressional

alias_dict_T['li_GAPI_D'] = ['GRD', 'SGRD', 'ECGRD', 'SGR'] # from Density
alias_dict_T['li_GAPI_R']  = ['ECGRR', 'GRR'] # from resistivity
alias_dict_T['li_GAPI_S'] = ['GRN', 'ECGRS'] # from sonic
alias_dict_T['li_GAPI_N'] = ['GR_EDTC', 'GR_STGC', 'GR']  # normal Gamma API

alias_dict_T['li_IN_D'] = ['C1', 'LCAL', 'CALI', 'CALD', 'LCALD'] # from density
alias_dict_T['li_IN_R'] = ['CALI_SPCS', 'CALR'] # from resistivity
alias_dict_T['li_IN_HILT'] =  ['HCAL2R', 'HCAL_1', 'HCAL_2', 'HCALD', 'HCALR', 'HCALS', 'HCAL'] # from HILT
 
alias_dict_T['li_LB_D'] = ['TEND'] # from density
alias_dict_T['li_LB_R'] = ['TENR'] # from Resistivity
alias_dict_T['li_LB_S'] = ['TENS'] # from Sonic

alias_dict_T['li_BE'] = ['PEF_SLDT', 'PE', 'PEFZ', 'PEF', 'PEFS', 'PEFL']

alias_dict_T['li_MV'] = ['SPR']


alias_T = {"DTSM" :['DTSM'],
           
         "DEC_NP"  : alias_dict_T['li_DEC_NP'],
         "DEC_DP"  : alias_dict_T['li_DEC_DP'],
         "DEC_ST"  : alias_dict_T['li_DEC_ST'],

         "USF_S"  : alias_dict_T['li_USF_S'],
         "USF_P"  : alias_dict_T['li_USF_P'],

         "GAPI_D" : alias_dict_T['li_GAPI_D'],
         "GAPI_R" : alias_dict_T['li_GAPI_R'],
         "GAPI_S" : alias_dict_T['li_GAPI_S'],
         "GAPI_N" : alias_dict_T['li_GAPI_N'],

         "IN_D"   : alias_dict_T['li_IN_D'],
         "IN_R"   : alias_dict_T['li_IN_R'],
         "IN_HILT"  : alias_dict_T['li_IN_HILT'],

         "MV"   : alias_dict_T['li_MV'],

         "BE"   : alias_dict_T['li_BE'],

          "SH"  : alias_dict_T['li_SH'],
          "DP"  : alias_dict_T['li_DP'],
         "SFL"  : alias_dict_T['li_SFL'],

         "LB_D"  : alias_dict_T['li_LB_D'],
         "LB_R"  : alias_dict_T['li_LB_R'],
         "LB_S"  : alias_dict_T['li_LB_S']
 }

alias_dict = np.array( [alias_T, alias_F] )

# %% [markdown]
# ##### Training Data Download

# %%
if not os.path.exists('data'):
  print("Downloading Data...")
  # !gdown --id 1syUxq6XDKYLQerZ1rx5DVEvm03ugKW_w
  # !unzip -qq 'data.zip' -d 'data'
  # !rm 'data.zip'

data = np.array([
                  pd.read_csv('data/dataT.csv'), 
                   pd.read_csv('data/dataF.csv')   ])
# Out:
# Downloading Data...
# Downloading...
# From: https://drive.google.com/uc?id=1syUxq6XDKYLQerZ1rx5DVEvm03ugKW_w
# To: /content/data.zip
# 63.8MB [00:02, 30.1MB/s]

# %% [markdown]
# # Workflow - Main Class
# Workflow wrapped in a modular class

# %%
class WellLog:

  def __init__(self, filepath, alias_dict, data, valid = False, drop_col = [], thresh = 1 ):

    self.filepath = filepath
    self.test = []
    self.region = 'U'
    self.alias_dict = alias_dict
    self.data = data
    self.valid = valid
    self.drop_col = drop_col
    self.preds = []
    self.deploy = False
    self.ydep = []
    self.depth  = []
    self.thresh = thresh

    self.cluster_region()
    self.test_util()

  def cluster_region( self):

    las = lasio.read(self.filepath)
    lat = las.well['SLAT'].value
    lon = las.well['SLON'].value
    cluster_centers = [[5.80127095, 3.52103194],
                          [2.27100945, 7.48227453]]
    dist = []
    for x in cluster_centers:
     dist.append( (lat-x[0])**2 +  (lon-x[1])**2 )
    if dist[0]<dist[1]:
      self.region = 'T'
    else:
      self.region = 'F'
    print('Region : {}'.format(self.region))

  def id(self,x):
    if x == 'T':
      return 0
    else:
      return 1

  def wellydf( self, df, alias_dict ):

      df2 = pd.DataFrame()
      for alias, columns in alias_dict.items(): 
        for column in columns:
          if column in df.columns.values:
            df2[alias] = df[column]
            break
      return df2

  def test_util( self):

    temp = lasio.read(self.filepath).df()
    self.depth = temp.index
    self.test = self.wellydf( temp , alias_dict[self.id(self.region)] )
    self.test.dropna(axis=1, how='all', inplace=True)

    if 'DTSM' in self.test.columns:
      print("\nDEPLOY FILE\n")
      self.test = self.test[self.test['DTSM'].notna()]
      self.deploy = True
      self.ydep = self.test['DTSM']
      self.test.drop(columns= ['DTSM'], inplace=True)

    print(self.test.info())
    if len(self.drop_col)>0:
      print("Dropping Selected Columns...")
      self.test_clean(self.drop_col,apply = 1)

  def test_clean(self, drop_col = [], apply = 0 ):
      
      temp = self.test.drop(columns = drop_col, axis =1)
      print(temp.info())
      if apply:
        self.test = temp

  def train(self, model = 'both'):

    xtrain = self.data[ self.id(self.region) ]
    col_list = list(self.test.columns)
    col_list.append('DTSM')
    xtrain = xtrain[col_list]
    col_list.pop()
    xtrain = xtrain[xtrain['DTSM'].notna()]

    thresh = int((len(col_list))//2)+ self.thresh
    xtrain = xtrain.dropna( thresh = thresh)
    ytrain = xtrain['DTSM']
    xtrain.drop(columns= ['DTSM'], inplace=True)
    
    print('Training data : {}'.format(len(xtrain)) )

    pred = []

    if model=='xgb' or model=='both':
      print("\nTraining XGB...")
      xgb_r = xg.XGBRegressor(objective='reg:squarederror',
                              random_state = 1,
                              tree_method = 'gpu_hist',
                            n_estimators =1000,
                            max_depth = 8)
      pred.append(self.train_util(xgb_r,xtrain,ytrain))

    if model=='cat' or model=='both':
      print("\nTraining CAT...")
      cat = CatBoostRegressor(verbose = 0,learning_rate  = 0.01,
                              task_type='GPU',
                              random_state = 1,
                              iterations = 1500, depth = 8)
      pred.append(self.train_util(cat, xtrain, ytrain))

    if (len(pred)>1):
      print("\nEnsembling...")

    if self.deploy:
      print('Deploy Weighted(1:3) RMSE :{}'.format( np.sqrt(MSE(self.ydep.values, (pred[0]+4*pred[1])/5)) ))
      print( (pred[0]+4*pred[1])/5 ) 

    if len(pred) >1:
      pred[0] = (pred[0]+4*pred[1])/5

    self.preds = pred[0]

  def train_util(self,model,xtrain,ytrain):

    if self.valid:
      xtrain, test_x, ytrain, test_y = train_test_split(xtrain, ytrain, 
                                                        test_size=0.2,
                                                        random_state= 42)
    a = time.time()
    model.fit( xtrain , ytrain )
    b = time.time()
    print('Train time :{}'.format(b-a))

    if self.valid:
      a = time.time()
      pred = model.predict(test_x)
      b = time.time()
      print('Valid time :{}'.format(b-a))
      rmse = np.sqrt(MSE(test_y, pred))
      print('Valid RMSE :{}'.format(rmse))

    pred = model.predict(self.test)

    if self.deploy:
      rmse = np.sqrt(MSE(self.ydep.values, pred))
      print('Deploy RMSE :{}'.format(rmse))
      print(pred)

    return pred

  def predictions(self, filename = ''):
    if len(filename) > 0:
      x = pd.DataFrame()
      x['Depth'] = self.depth
      x['DTSM'] = self.preds
      print(x.head())
      print(x.tail())
      x.to_excel(filename + '.xlsx', index=False)

    return self.preds

# %% [markdown]
# # Test a Single File
# Using the above class for testing a file <br>
# *Add the file to be tested in this notebook*

# %%
'''
Create an object of above class

Parameters :

filepath : path of LAS file
alias_dict : alias dictionary, initalized in pre-requisites section
data : preprocessed training dataframes, initalized in pre-requisites section
valid : boolean, True for validation, default - False
drop_col : list of aliases to drop from test file, defualt - any empty list

'''

test = WellLog( 'folder-name/0a7822c59487_TGS.las', alias_dict, data  )

# %%
'''
Training data

Parameters :
model : ''CAT' / 'XGB' / 'both' , default - both

'''

test.train()

# %%
'''
Returns predictions

Parameters :
filename : filename for xlsx file, saving the predictions (optional)
'''

test.predictions( 'file-name')

# %% [markdown]
# # Submission Test Files
# Producing results on submission test files

# %%
# !gdown --id 1-43M2dHo-p7sBMQv0DK2RK8ZC1cNpVUC
# !unzip -qq final-data.zip -d 'test-data'
os.remove("final-data.zip")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-43M2dHo-p7sBMQv0DK2RK8ZC1cNpVUC
# To: /content/final-data.zip
# 6.83MB [00:00, 25.9MB/s]

# %%
x = [  

'63250f7d463b_TGS.las',
'638f2cc65681_TGS.las',
'fca03aa6acde_TGS.las',
'3369b6f8fb6f_TGS.las',
'8e37531ba266_TGS.las',
'eed1e9537976_TGS.las',
'113412eec2a6_TGS.las',
'ff7845ea074d_TGS.las',
'34a80ab7a5fa_TGS.las',
'84c5fb9cc880_TGS.las', 
'7595ba9fb314_TGS.las',
'302460e3021a_TGS.las',
'2f96a5f92418_TGS.las',
'1684cc35f399_TGS.las'
]

for filename in tqdm(x):
    print('___________________________________________________________________')
    print(filename)
    test = WellLog( 'test-data/' + filename, alias_dict, data, valid=0  )
    test.train()
    test.predictions( filename[:-4] )
# Out:
# HBox(children=(FloatProgress(value=0.0, max=14.0), HTML(value='')))
# ___________________________________________________________________
# 63250f7d463b_TGS.las
# Region : F
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 13883 entries, 5241.0 to 12182.0
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_D   13882 non-null  float64
#  1   DEC_N   13871 non-null  float64
#  2   USF_S   13882 non-null  float64
#  3   USF_P   13882 non-null  float64
#  4   IN_D    13882 non-null  float64
#  5   MV      13883 non-null  float64
#  6   BE      13433 non-null  float64
#  7   SH      13883 non-null  float64
#  8   DP      13794 non-null  float64
# dtypes: float64(9)
# memory usage: 1.1 MB
# None
# Training data : 515065
#
# Training XGB...
# Train time :13.865854263305664
#
# Training CAT...
# Train time :69.99051809310913
#
# Ensembling...
#     Depth        DTSM
# 0  5241.0  113.033036
# 1  5241.5  123.132374
# 2  5242.0  116.541283
# 3  5242.5  115.188701
# 4  5243.0  121.831093
#          Depth        DTSM
# 13878  12180.0  138.883628
# 13879  12180.5  137.220938
# 13880  12181.0  134.242746
# 13881  12181.5  134.918067
# 13882  12182.0  135.898448
# ___________________________________________________________________
# 638f2cc65681_TGS.las
# Region : F
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1737 entries, 5477.0 to 6345.0
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_D   1737 non-null   float64
#  1   DEC_N   1737 non-null   float64
#  2   USF_P   1737 non-null   float64
#  3   GAPI_D  1693 non-null   float64
#  4   IN_D    1737 non-null   float64
#  5   BE      1737 non-null   float64
# dtypes: float64(6)
# memory usage: 95.0 KB
# None
# Training data : 706177
#
# Training XGB...
# Train time :13.48586130142212
#
# Training CAT...
# Train time :11.522074222564697
#
# Ensembling...
#     Depth        DTSM
# 0  5477.0  111.680871
# 1  5477.5  111.281248
# 2  5478.0  108.942541
# 3  5478.5  108.927322
# 4  5479.0  104.464201
#        Depth        DTSM
# 1732  6343.0  154.558763
# 1733  6343.5  154.491398
# 1734  6344.0  154.287867
# 1735  6344.5  154.300184
# 1736  6345.0  154.123439
# ___________________________________________________________________
# fca03aa6acde_TGS.las
# Region : F
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1465 entries, 10797.0 to 11529.0
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_D   1465 non-null   float64
#  1   DEC_N   1465 non-null   float64
#  2   USF_P   1465 non-null   float64
#  3   GAPI_D  1465 non-null   float64
#  4   GAPI_R  1465 non-null   float64
#  5   IN_R    1465 non-null   float64
#  6   BE      1465 non-null   float64
#  7   SH      1465 non-null   float64
#  8   DP      1465 non-null   float64
# dtypes: float64(9)
# memory usage: 114.5 KB
# None
# Training data : 525493
#
# Training XGB...
# Train time :13.587666749954224
#
# Training CAT...
# Train time :10.557554960250854
#
# Ensembling...
#      Depth        DTSM
# 0  10797.0  101.488352
# 1  10797.5   99.702167
# 2  10798.0  101.576206
# 3  10798.5  101.023024
# 4  10799.0  100.561351
#         Depth       DTSM
# 1460  11527.0  95.308502
# 1461  11527.5  94.546512
# 1462  11528.0  94.657774
# 1463  11528.5  94.384412
# 1464  11529.0  93.825541
# ___________________________________________________________________
# 3369b6f8fb6f_TGS.las
# Region : F
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1401 entries, 2961.0 to 3661.0
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_D   1401 non-null   float64
#  1   DEC_N   1401 non-null   float64
#  2   USF_P   1401 non-null   float64
#  3   GAPI_D  1401 non-null   float64
#  4   GAPI_R  1401 non-null   float64
#  5   IN_D    1401 non-null   float64
#  6   IN_R    1401 non-null   float64
#  7   BE      1401 non-null   float64
#  8   LBF_D   1401 non-null   float64
#  9   LBF_R   1401 non-null   float64
#  10  LBF_S   1401 non-null   float64
#  11  SH      1401 non-null   float64
#  12  DP      1401 non-null   float64
# dtypes: float64(13)
# memory usage: 153.2 KB
# None
# Training data : 288885
#
# Training XGB...
# Train time :11.466034173965454
#
# Training CAT...
# Train time :8.947084426879883
#
# Ensembling...
#     Depth       DTSM
# 0  2961.0  96.055991
# 1  2961.5  96.253757
# 2  2962.0  96.913593
# 3  2962.5  97.135421
# 4  2963.0  98.286282
#        Depth        DTSM
# 1396  3659.0  100.199517
# 1397  3659.5   98.072343
# 1398  3660.0   97.070767
# 1399  3660.5   97.061010
# 1400  3661.0   97.245127
# ___________________________________________________________________
# 8e37531ba266_TGS.las
# Region : F
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 5031 entries, 2313.0 to 4828.0
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_D   4977 non-null   float64
#  1   DEC_N   4941 non-null   float64
#  2   USF_P   5029 non-null   float64
#  3   GAPI_D  4923 non-null   float64
#  4   IN_D    4977 non-null   float64
#  5   BE      4977 non-null   float64
#  6   SH      5031 non-null   float64
#  7   DP      5031 non-null   float64
# dtypes: float64(8)
# memory usage: 353.7 KB
# None
# Training data : 607852
#
# Training XGB...
# Train time :14.055040836334229
#
# Training CAT...
# Train time :10.980461835861206
#
# Ensembling...
#     Depth       DTSM
# 0  2313.0  97.454186
# 1  2313.5  98.190640
# 2  2314.0  96.560807
# 3  2314.5  96.123730
# 4  2315.0  96.259066
#        Depth       DTSM
# 5026  4826.0  86.208755
# 5027  4826.5  86.090760
# 5028  4827.0  85.995347
# 5029  4827.5  90.398071
# 5030  4828.0  90.485902
# ___________________________________________________________________
# eed1e9537976_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 3957 entries, 7997.0 to 9975.0
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DEC_NP   3732 non-null   float64
#  1   DEC_DP   3957 non-null   float64
#  2   USF_S    3927 non-null   float64
#  3   USF_P    3927 non-null   float64
#  4   GAPI_R   3929 non-null   float64
#  5   IN_HILT  3957 non-null   float64
#  6   MV       3957 non-null   float64
#  7   BE       3957 non-null   float64
#  8   SH       3934 non-null   float64
#  9   DP       3957 non-null   float64
# dtypes: float64(10)
# memory usage: 340.1 KB
# None
# Training data : 486817
#
# Training XGB...
# Train time :13.595177173614502
#
# Training CAT...
# Train time :10.662212133407593
#
# Ensembling...
#     Depth        DTSM
# 0  7997.0  142.243704
# 1  7997.5  144.086907
# 2  7998.0  132.337525
# 3  7998.5  128.246032
# 4  7999.0  128.041610
#        Depth        DTSM
# 3952  9973.0  119.167728
# 3953  9973.5  122.952094
# 3954  9974.0  123.446464
# 3955  9974.5  116.387157
# 3956  9975.0  112.443624
# ___________________________________________________________________
# 113412eec2a6_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 12846 entries, 5000.0 to 11422.5
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_NP  6713 non-null   float64
#  1   DEC_DP  7093 non-null   float64
#  2   USF_P   12844 non-null  float64
#  3   GAPI_R  12636 non-null  float64
#  4   MV      12846 non-null  float64
#  5   BE      7126 non-null   float64
#  6   SH      12742 non-null  float64
#  7   DP      12582 non-null  float64
# dtypes: float64(8)
# memory usage: 903.2 KB
# None
# Training data : 521790
#
# Training XGB...
# Train time :14.04903531074524
#
# Training CAT...
# Train time :10.570903539657593
#
# Ensembling...
#     Depth        DTSM
# 0  5000.0  153.629162
# 1  5000.5  153.341543
# 2  5001.0  152.778985
# 3  5001.5  154.859330
# 4  5002.0  152.409980
#          Depth       DTSM
# 12841  11420.5  93.341415
# 12842  11421.0  93.120277
# 12843  11421.5  95.242397
# 12844  11422.0  97.240682
# 12845  11422.5  97.321345
# ___________________________________________________________________
# ff7845ea074d_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 3671 entries, 6984.0 to 8819.0
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_NP  3655 non-null   float64
#  1   DEC_DP  3605 non-null   float64
#  2   USF_P   3671 non-null   float64
#  3   GAPI_D  3655 non-null   float64
#  4   GAPI_R  3665 non-null   float64
#  5   IN_D    3655 non-null   float64
#  6   MV      3665 non-null   float64
#  7   BE      3655 non-null   float64
#  8   DP      3657 non-null   float64
#  9   LB_D    3655 non-null   float64
#  10  LB_R    3671 non-null   float64
#  11  LB_S    3671 non-null   float64
# dtypes: float64(12)
# memory usage: 372.8 KB
# None
# Training data : 388760
#
# Training XGB...
# Train time :13.63656735420227
#
# Training CAT...
# Train time :9.549764394760132
#
# Ensembling...
#     Depth        DTSM
# 0  6984.0  101.086029
# 1  6984.5  102.098268
# 2  6985.0  100.650588
# 3  6985.5  104.021800
# 4  6986.0  104.071190
#        Depth       DTSM
# 3666  8817.0  93.645116
# 3667  8817.5  97.550288
# 3668  8818.0  95.757249
# 3669  8818.5  95.191188
# 3670  8819.0  99.949390
# ___________________________________________________________________
# 34a80ab7a5fa_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 2019 entries, 7887.0 to 8896.0
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DEC_NP   1928 non-null   float64
#  1   DEC_DP   2019 non-null   float64
#  2   USF_P    2019 non-null   float64
#  3   GAPI_R   2019 non-null   float64
#  4   GAPI_N   425 non-null    float64
#  5   IN_HILT  2019 non-null   float64
#  6   MV       2019 non-null   float64
#  7   BE       2019 non-null   float64
#  8   SH       2019 non-null   float64
#  9   DP       2019 non-null   float64
# dtypes: float64(10)
# memory usage: 173.5 KB
# None
# Training data : 485258
#
# Training XGB...
# Train time :13.66627049446106
#
# Training CAT...
# Train time :10.705993175506592
#
# Ensembling...
#     Depth        DTSM
# 0  7887.0  131.084667
# 1  7887.5  133.126431
# 2  7888.0  133.151970
# 3  7888.5  129.185271
# 4  7889.0  128.602561
#        Depth        DTSM
# 2014  8894.0  134.838187
# 2015  8894.5  135.482038
# 2016  8895.0  136.515687
# 2017  8895.5  134.834046
# 2018  8896.0  133.532357
# ___________________________________________________________________
# 84c5fb9cc880_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1291 entries, 16002.0 to 16650.0
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_NP  1291 non-null   float64
#  1   USF_P   1290 non-null   float64
#  2   GAPI_R  1291 non-null   float64
#  3   IN_D    1291 non-null   float64
#  4   MV      1291 non-null   float64
# dtypes: float64(5)
# memory usage: 60.5 KB
# None
# Training data : 646070
#
# Training XGB...
# Train time :13.012623310089111
#
# Training CAT...
# Train time :11.261929750442505
#
# Ensembling...
#      Depth        DTSM
# 0  16002.0  163.415953
# 1  16002.5  164.603090
# 2  16003.0  163.904030
# 3  16003.5  158.841819
# 4  16004.0  156.355590
#         Depth        DTSM
# 1286  16648.0  150.305555
# 1287  16648.5  149.409368
# 1288  16649.0  149.289230
# 1289  16649.5  149.684338
# 1290  16650.0  149.429596
# ___________________________________________________________________
# 7595ba9fb314_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1893 entries, 10398.0 to 11344.0
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_NP  1893 non-null   float64
#  1   USF_P   1893 non-null   float64
#  2   GAPI_D  1893 non-null   float64
#  3   GAPI_R  1893 non-null   float64
#  4   IN_D    1893 non-null   float64
#  5   MV      1893 non-null   float64
#  6   BE      1893 non-null   float64
#  7   DP      1893 non-null   float64
#  8   SFL     1893 non-null   float64
#  9   LB_D    1893 non-null   float64
#  10  LB_R    1893 non-null   float64
#  11  LB_S    1893 non-null   float64
# dtypes: float64(12)
# memory usage: 192.3 KB
# None
# Training data : 329394
#
# Training XGB...
# Train time :12.966477870941162
#
# Training CAT...
# Train time :8.992395401000977
#
# Ensembling...
#      Depth        DTSM
# 0  10398.0  120.677753
# 1  10398.5  119.375802
# 2  10399.0  118.436872
# 3  10399.5  119.473756
# 4  10400.0  121.023214
#         Depth        DTSM
# 1888  11342.0  166.788245
# 1889  11342.5  166.455553
# 1890  11343.0  165.809173
# 1891  11343.5  166.178292
# 1892  11344.0  165.450145
# ___________________________________________________________________
# 302460e3021a_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 10745 entries, 586.0 to 6066.0
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DEC_NP   10745 non-null  float64
#  1   DEC_DP   10745 non-null  float64
#  2   USF_P    10737 non-null  float64
#  3   GAPI_R   10745 non-null  float64
#  4   IN_HILT  10745 non-null  float64
#  5   MV       10745 non-null  float64
#  6   BE       10744 non-null  float64
#  7   SH       10745 non-null  float64
#  8   DP       10745 non-null  float64
# dtypes: float64(9)
# memory usage: 839.5 KB
# None
# Training data : 536446
#
# Training XGB...
# Train time :13.957600593566895
#
# Training CAT...
# Train time :10.930583238601685
#
# Ensembling...
#    Depth        DTSM
# 0  586.0  149.159731
# 1  586.5  182.663140
# 2  587.0  176.106161
# 3  587.5  180.397107
# 4  588.0  180.961768
#         Depth        DTSM
# 10740  6064.0  115.475903
# 10741  6064.5  109.557564
# 10742  6065.0  111.603201
# 10743  6065.5  110.685007
# 10744  6066.0  116.029024
# ___________________________________________________________________
# 2f96a5f92418_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 3497 entries, 12787.5 to 14535.5
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DEC_NP   3478 non-null   float64
#  1   DEC_DP   3497 non-null   float64
#  2   USF_P    3495 non-null   float64
#  3   GAPI_R   3463 non-null   float64
#  4   IN_HILT  3488 non-null   float64
#  5   MV       3497 non-null   float64
#  6   BE       3489 non-null   float64
#  7   DP       3485 non-null   float64
# dtypes: float64(8)
# memory usage: 245.9 KB
# None
# Training data : 520947
#
# Training XGB...
# Train time :14.095128297805786
#
# Training CAT...
# Train time :10.542760133743286
#
# Ensembling...
#      Depth        DTSM
# 0  12787.5   96.875125
# 1  12788.0   96.681010
# 2  12788.5  103.989536
# 3  12789.0  102.525136
# 4  12789.5  101.350171
#         Depth        DTSM
# 3492  14533.5  126.926584
# 3493  14534.0  128.272382
# 3494  14534.5  129.314814
# 3495  14535.0  131.595747
# 3496  14535.5  134.297422
# ___________________________________________________________________
# 1684cc35f399_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 13255 entries, 5994.0 to 12621.0
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_NP  9664 non-null   float64
#  1   DEC_DP  11021 non-null  float64
#  2   USF_P   13255 non-null  float64
#  3   GAPI_R  13255 non-null  float64
#  4   IN_D    11291 non-null  float64
#  5   IN_R    10593 non-null  float64
#  6   MV      13255 non-null  float64
#  7   BE      7979 non-null   float64
#  8   DP      13255 non-null  float64
#  9   SFL     13255 non-null  float64
# dtypes: float64(10)
# memory usage: 1.1 MB
# None
# Training data : 457864
#
# Training XGB...
# Train time :13.541703462600708
#
# Training CAT...
# Train time :10.22417426109314
#
# Ensembling...
#     Depth        DTSM
# 0  5994.0  135.257007
# 1  5994.5  133.409858
# 2  5995.0  127.587242
# 3  5995.5  121.669765
# 4  5996.0  120.141136
#          Depth        DTSM
# 13250  12619.0  111.397785
# 13251  12619.5  111.180490
# 13252  12620.0  108.214085
# 13253  12620.5  105.758063
# 13254  12621.0  103.881407

# %%
temp = dict()
temp['00d02be79f49_TGS.las'] = []
temp['ae16a9f64878_TGS.las'] = ['IN_D', 'DP', 'SFL']
temp['94c1f5cae85c_TGS.las'] = ['BE']
temp['ed48bda2217f_TGS.las'] = []
temp['20372701d5e2_TGS.las'] = ['DEC_DP', 'IN_HILT', 'BE', 'DP']
temp['0a7822c59487_TGS.las'] = ['DEC_T', 'IN_HILT', 'BE', 'SH', 'DP']

x = [
'00d02be79f49_TGS.las',
'ae16a9f64878_TGS.las',
'94c1f5cae85c_TGS.las',
'ed48bda2217f_TGS.las',
'20372701d5e2_TGS.las',
'0a7822c59487_TGS.las'
]

for filename in tqdm(x):
    print('___________________________________________________________________')
    print(filename)
    test = WellLog( 'test-data/' + filename, alias_dict, data, valid=0,
                   drop_col = temp[filename] )
    test.train()
    test.predictions( filename[:-4] )
# Out:
# HBox(children=(FloatProgress(value=0.0, max=6.0), HTML(value='')))
# ___________________________________________________________________
# 00d02be79f49_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 1307 entries, 9912.0 to 10565.0
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_NP  1293 non-null   float64
#  1   DEC_DP  1307 non-null   float64
#  2   USF_P   575 non-null    float64
#  3   GAPI_R  1275 non-null   float64
#  4   IN_D    1307 non-null   float64
#  5   MV      1307 non-null   float64
#  6   DP      1307 non-null   float64
# dtypes: float64(7)
# memory usage: 81.7 KB
# None
# Training data : 631810
#
# Training XGB...
# Train time :14.036465406417847
#
# Training CAT...
# Train time :11.312457084655762
#
# Ensembling...
#     Depth        DTSM
# 0  9912.0  100.066396
# 1  9912.5   99.665523
# 2  9913.0  101.298541
# 3  9913.5  102.906530
# 4  9914.0  101.961048
#         Depth        DTSM
# 1302  10563.0  112.102998
# 1303  10563.5  112.222685
# 1304  10564.0  112.064954
# 1305  10564.5  111.724287
# 1306  10565.0  112.091014
# ___________________________________________________________________
# ae16a9f64878_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 21678 entries, 5460.0 to 16616.0
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DEC_NP   20620 non-null  float64
#  1   DEC_DP   15423 non-null  float64
#  2   USF_P    21651 non-null  float64
#  3   GAPI_R   21678 non-null  float64
#  4   IN_D     2212 non-null   float64
#  5   IN_HILT  15739 non-null  float64
#  6   MV       21678 non-null  float64
#  7   BE       14473 non-null  float64
#  8   SH       16218 non-null  float64
#  9   DP       4881 non-null   float64
#  10  SFL      4881 non-null   float64
# dtypes: float64(11)
# memory usage: 2.0 MB
# None
# Dropping Selected Columns...
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 21678 entries, 5460.0 to 16616.0
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DEC_NP   20620 non-null  float64
#  1   DEC_DP   15423 non-null  float64
#  2   USF_P    21651 non-null  float64
#  3   GAPI_R   21678 non-null  float64
#  4   IN_HILT  15739 non-null  float64
#  5   MV       21678 non-null  float64
#  6   BE       14473 non-null  float64
#  7   SH       16218 non-null  float64
# dtypes: float64(8)
# memory usage: 1.5 MB
# None
# Training data : 495590
#
# Training XGB...
# Train time :13.742658615112305
#
# Training CAT...
# Train time :10.38567066192627
#
# Ensembling...
#     Depth        DTSM
# 0  5460.0  157.927429
# 1  5460.5  158.262570
# 2  5461.0  159.537356
# 3  5461.5  159.524802
# 4  5462.0  159.124540
#          Depth        DTSM
# 21673  16614.0  169.782731
# 21674  16614.5  168.835315
# 21675  16615.0  189.771678
# 21676  16615.5  190.650541
# 21677  16616.0  190.653587
# ___________________________________________________________________
# 94c1f5cae85c_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 16926 entries, 16900.0 to 25398.0
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_NP  15809 non-null  float64
#  1   DEC_DP  16914 non-null  float64
#  2   USF_P   16926 non-null  float64
#  3   GAPI_D  16902 non-null  float64
#  4   IN_D    16926 non-null  float64
#  5   BE      5702 non-null   float64
#  6   DP      15877 non-null  float64
# dtypes: float64(7)
# memory usage: 1.0 MB
# None
# Dropping Selected Columns...
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 16926 entries, 16900.0 to 25398.0
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_NP  15809 non-null  float64
#  1   DEC_DP  16914 non-null  float64
#  2   USF_P   16926 non-null  float64
#  3   GAPI_D  16902 non-null  float64
#  4   IN_D    16926 non-null  float64
#  5   DP      15877 non-null  float64
# dtypes: float64(6)
# memory usage: 925.6 KB
# None
# Training data : 500247
#
# Training XGB...
# Train time :12.53783631324768
#
# Training CAT...
# Train time :10.289707660675049
#
# Ensembling...
#      Depth        DTSM
# 0  16900.0  125.557356
# 1  16900.5  119.989470
# 2  16901.0  113.266614
# 3  16901.5  112.836993
# 4  16902.0  113.905440
#          Depth        DTSM
# 16921  25396.0  106.556856
# 16922  25396.5  101.081490
# 16923  25397.0  100.360889
# 16924  25397.5  100.411986
# 16925  25398.0  100.318021
# ___________________________________________________________________
# ed48bda2217f_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 24122 entries, 3085.0 to 15155.0
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DEC_NP   13031 non-null  float64
#  1   USF_P    24122 non-null  float64
#  2   GAPI_R   24122 non-null  float64
#  3   IN_HILT  13005 non-null  float64
#  4   MV       24122 non-null  float64
#  5   BE       13021 non-null  float64
# dtypes: float64(6)
# memory usage: 1.3 MB
# None
# Training data : 587896
#
# Training XGB...
# Train time :13.118049144744873
#
# Training CAT...
# Train time :11.015175580978394
#
# Ensembling...
#     Depth        DTSM
# 0  3085.0  139.510147
# 1  3085.5  139.150638
# 2  3086.0  135.859940
# 3  3086.5  163.718436
# 4  3087.0  157.941507
#          Depth        DTSM
# 24117  15153.0  162.301465
# 24118  15153.5  157.035109
# 24119  15154.0  154.340453
# 24120  15154.5  137.478551
# 24121  15155.0  133.299040
# ___________________________________________________________________
# 20372701d5e2_TGS.las
# Region : T
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 2147 entries, 13105.0 to 14178.0
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DEC_NP   2101 non-null   float64
#  1   DEC_DP   1 non-null      float64
#  2   USF_P    2147 non-null   float64
#  3   GAPI_R   2033 non-null   float64
#  4   IN_HILT  1 non-null      float64
#  5   MV       2147 non-null   float64
#  6   BE       1 non-null      float64
#  7   DP       1 non-null      float64
# dtypes: float64(8)
# memory usage: 151.0 KB
# None
# Dropping Selected Columns...
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 2147 entries, 13105.0 to 14178.0
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_NP  2101 non-null   float64
#  1   USF_P   2147 non-null   float64
#  2   GAPI_R  2033 non-null   float64
#  3   MV      2147 non-null   float64
# dtypes: float64(4)
# memory usage: 83.9 KB
# None
# Training data : 612755
#
# Training XGB...
# Train time :12.97866702079773
#
# Training CAT...
# Train time :10.705559015274048
#
# Ensembling...
#      Depth        DTSM
# 0  13105.0  171.454471
# 1  13105.5  168.498908
# 2  13106.0  169.465470
# 3  13106.5  168.664100
# 4  13107.0  169.755692
#         Depth        DTSM
# 2142  14176.0  179.500306
# 2143  14176.5  179.500306
# 2144  14177.0  178.979187
# 2145  14177.5  178.979187
# 2146  14178.0  178.979187
# ___________________________________________________________________
# 0a7822c59487_TGS.las
# Region : F
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 5135 entries, 5868.0 to 8435.0
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DEC_D    4117 non-null   float64
#  1   DEC_N    4199 non-null   float64
#  2   DEC_T    185 non-null    float64
#  3   DEC_S    5111 non-null   float64
#  4   USF_P    5111 non-null   float64
#  5   GAPI_D   4253 non-null   float64
#  6   IN_R     4197 non-null   float64
#  7   IN_HILT  211 non-null    float64
#  8   BE       211 non-null    float64
#  9   LBF_D    4461 non-null   float64
#  10  LBF_S    5135 non-null   float64
#  11  SH       231 non-null    float64
#  12  DP       4197 non-null   float64
# dtypes: float64(13)
# memory usage: 561.6 KB
# None
# Dropping Selected Columns...
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 5135 entries, 5868.0 to 8435.0
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DEC_D   4117 non-null   float64
#  1   DEC_N   4199 non-null   float64
#  2   DEC_S   5111 non-null   float64
#  3   USF_P   5111 non-null   float64
#  4   GAPI_D  4253 non-null   float64
#  5   IN_R    4197 non-null   float64
#  6   LBF_D   4461 non-null   float64
#  7   LBF_S   5135 non-null   float64
# dtypes: float64(8)
# memory usage: 361.1 KB
# None
# Training data : 299100
#
# Training XGB...
# Train time :12.069207906723022
#
# Training CAT...
# Train time :8.49506425857544
#
# Ensembling...
#     Depth        DTSM
# 0  5868.0  113.350511
# 1  5868.5  119.360047
# 2  5869.0  119.428246
# 3  5869.5  119.338491
# 4  5870.0  119.338772
#        Depth        DTSM
# 5130  8433.0  124.400046
# 5131  8433.5  124.945549
# 5132  8434.0  127.880557
# 5133  8434.5  127.880557
# 5134  8435.0  127.880557

# %%
import glob
pred_files = glob.glob('*.xlsx')

# %%
# !mkdir predictions2
import shutil
for pred_file in pred_files:
  shutil.move( pred_file, 'predictions2' + '/' + pred_file )
shutil.make_archive( 'predictions2' , 'zip', 'predictions2' )
# Out:
# '/content/predictions2.zip'
